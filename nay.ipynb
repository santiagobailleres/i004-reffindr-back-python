# %%
# %%time
import requests
import pandas as pd

url = 'http://127.0.0.1:5000/argenprop'

# Parámetros de la solicitud
params = {'pais': 'argentina', 'limite': 300}
response = requests.get(url, params=params)

data = response.json()
df = pd.DataFrame(data)
# Out:
# CPU times: total: 1.27 s
# Wall time: 5min 2s

# %% [markdown]
# De la siguiente forma, se crea un df copiado en la variable df_nay con lo que no corre peligro si se hacen transformaciones y sale mal

# %%
df_nay = df.copy()

# %%
# Leer el archivo CSV en lugar de un archivo Excel
csv_path = 'C:\\Users\\Usuario\\Desktop\\IGROWKER - REFFINDR\\DataA -Role\\i004-reffindr-back-python\\Data_ficticia\\Users_Ficticios_IA.csv'
df_users = pd.read_csv(csv_path)
df_users
# Out:
#         Name  LastName       Dni               Phone  \
# 0     Isaias    Lucena  63142191  +54 9 14-4193-4616
# 1     Susana    Segura  34079113  +54 9 13-4929-6761
# 2     Cintia      Diaz  91561184  +54 9 20-5624-9452
# 3       Irma     Campo  78322155  +54 9 15-6016-4939
# 4     Hector   Uriarte  65513184  +54 9 21-4623-4951
# ..       ...       ...       ...                 ...
# 495   Gracia    Santos  74209416  +54 9 19-5934-1122
# 496   Anabel    Alcala  54211584  +54 9 16-4156-9202
# 497    Aaron  Cespedes  57106311  +54 9 19-4203-1698
# 498     Lara   Linares  38253095  +54 9 13-4618-6453
# 499  Pascual   Casares  76298449  +54 9 22-4454-6317
#
#                                                Address   BirthDate  \
# 0             Calle Charo Jordá 744, Trelew, Argentina  1972-04-26
# 1       Via Pío Carranza 864, Mar del Plata, Argentina  1972-04-25
# 2         Vial Eliana Bárcena 169, La Plata, Argentina  1986-01-03
# ...
